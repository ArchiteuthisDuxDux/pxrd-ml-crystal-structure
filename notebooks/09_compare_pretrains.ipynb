# %% [markdown]
# # 09. Сравнение synthetic pretrain V1 и V2
#
# Обе архитектуры оцениваются одном синтетическом validation split; дополнительно выполняется zero-shot оценка на real FT-пуле.

# %%
from pathlib import Path
import os
import sys

PROJECT_ROOT = Path.cwd().resolve()

if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

if not (PROJECT_ROOT / "src").exists():
    raise RuntimeError("Неверный путь.")

os.chdir(PROJECT_ROOT)

if str(PROJECT_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "src"))

from project_paths import *
ensure_project_directories()

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: D:\Users\user\Desktop\DS_XRD_project

# %%
import subprocess

def run_script(script_name, *args):

    # Run one reproducible pipeline stage and stream its output.
    
    command = [sys.executable, str(PROJECT_ROOT / "src" / script_name), *map(str, args)]

    print("Running:", " ".join(command))
    subprocess.run(command, cwd=PROJECT_ROOT, check=True)

# %%
run_script("diag_pretrain.py")
# Out:
# Running: d:\Dev\envs\study\python.exe D:\Users\user\Desktop\DS_XRD_project\src\diag_pretrain.py

# %%
run_script("compare_v1_v2.py")
# Out:
# Running: d:\Dev\envs\study\python.exe D:\Users\user\Desktop\DS_XRD_project\src\compare_v1_v2.py

# %%
from IPython.display import Image, display

for name in ["diag_pretrain_breakdown.png", "pretrain_full_losses.png", "pretrain_v2_full_losses.png"]:
    path = OUTPUTS_DIR / name

    if path.exists():
        display(Image(filename=str(path)))

#V1

# %% [markdown]
# ## Вывод
#
# V2 проверяется как увеличение ёмкости при неизменных данных и split.
