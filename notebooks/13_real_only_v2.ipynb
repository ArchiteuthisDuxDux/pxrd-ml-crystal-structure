# %% [markdown]
# # 13. Контроль Real-only V2
#
# Этот ноутбук сохраняет проверенную реализацию исходного эксперимента и имена его
# артефактов. Запускайте **Restart Kernel and Run All Cells** после выполнения всех
# предыдущих пронумерованных ноутбуков.
#
# Все входы, кроме исходных raw-данных из `config/raw_sources.json`, создаются внутри
# этого проекта. Результаты записываются в `outputs/`, а модели — в `checkpoints/`.

# %%
from pathlib import Path
import os
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if not (PROJECT_ROOT / "src").exists():
    raise RuntimeError("Неверный путь.")

os.chdir(PROJECT_ROOT)
if str(PROJECT_ROOT / "src") not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT / "src"))

from project_paths import *
ensure_project_directories()

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: D:\Users\user\Desktop\DS_XRD_project

# %% [markdown]
# # Real-only v2
# Обучение той же архитектуры XRDNetV2 с нуля только на реальных размеченных данных.
#
# Запустите `MODE = 'quick'` для проверки или `MODE = 'cv'` для полного 5-fold GroupKFold. Результаты сохраняются в `outputs/real_only_v2_cv_summary.csv` и `outputs/real_only_vs_ft_v2_comparison.csv`.

# %% [markdown]
# ### Данные и промежуточные вычисления

# %%
# Real-only v2: та же XRDNetV2, обучение с нуля только на реальных данных
import json, math, random, time
from pathlib import Path
import numpy as np, pandas as pd, torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import GroupKFold

SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True
torch.backends.cudnn.benchmark = True
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', DEVICE, '|', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')

# MODE='quick' запускает один фолд для проверки; MODE='cv' — полный эксперимент.
# Бюджет совпадает с исходным циклом: 15 эпох synthetic pretrain + 50 эпох real FT = 65 эпох.
MODE = 'cv'
BASE = PROJECT_ROOT
DATA = BASE/'data'/'preprocessed'; OUT = BASE/'outputs'; CKPT_DIR = BASE/'checkpoints'
GRID_N = 4096; W = 3; IMPUTE_LAMBDA = 1.5406
SYSTEMS = ['triclinic','monoclinic','orthorhombic','tetragonal','trigonal','hexagonal','cubic']
HP = dict(batch=128, lr=1e-4, wd=1e-4, clip=1.0, epochs=65, warmup_frac=.1, n_folds=5)

stats = json.loads((OUT/'pretrain_stats.json').read_text())
VOCAB = stats['vocab']; EL_IDX = {e:i for i,e in enumerate(VOCAB)}
LAT_MEAN = np.array(stats['lat_mean']); LAT_STD = np.array(stats['lat_std'])
VOL_MEAN, VOL_STD = stats['vol_mean'], stats['vol_std']
index = pd.read_parquet(DATA/'index_preprocessed.parquet'); N_TOTAL = len(index)
X_MM = np.memmap(DATA/'X_intensity.f16', dtype=np.float16, mode='r', shape=(N_TOTAL,GRID_N))
M_MM = np.memmap(DATA/'M_mask.u8', dtype=np.uint8, mode='r', shape=(N_TOTAL,GRID_N))
row_of = dict(zip(index.sample_id, index.row_idx))
ft = pd.read_parquet(BASE/'data'/'clean'/'ft_pool_combined.parquet').copy()
ft['row_idx'] = ft.sample_id.map(row_of); assert ft.row_idx.notna().all()
ft['primary_wavelength'] = ft.primary_wavelength.fillna(IMPUTE_LAMBDA)
abc = ft[['lattice_a','lattice_b','lattice_c']].to_numpy(float)
ang = ft[['alpha','beta','gamma']].to_numpy(float)
ca,cb,cg = (np.cos(np.radians(ang[:,i])) for i in range(3))
t = 1-ca**2-cb**2-cg**2+2*ca*cb*cg
ft['V'] = abc.prod(1)*np.sqrt(np.clip(t,1e-12,None)); ft['lat6'] = list(np.hstack([np.log(abc),ang]))
# Out:
# device: cuda | NVIDIA GeForce RTX 3060 Ti

# %% [markdown]
# ### Функция `to_list`

# %%
def to_list(v):
    if isinstance(v,str):
        try: return json.loads(v)
        except Exception: return []
    if isinstance(v,(list,tuple,np.ndarray)): return [e for e in v if isinstance(e,str)]
    return []

# %% [markdown]
# ### Данные и промежуточные вычисления

# %%
ft['elements'] = ft.elements_list.apply(to_list)
ft['conn_key'] = ft.phase_compositions.astype(str)+'|'+ft.lattice_a.round(2).astype(str)
print('REAL-ONLY pool:',len(ft),'rows | groups:',ft.conn_key.nunique())
# Out:
# REAL-ONLY pool: 3475 rows | groups: 2029

# %% [markdown]
# ### Функция `build_labels`

# %%
def build_labels(frame):
    l2 = frame.secondary_wavelength.to_numpy(float)
    lam = np.stack([frame.primary_wavelength.to_numpy(float)/1.54,
                    np.nan_to_num(l2)/1.54,np.isfinite(l2).astype(np.float32)],1).astype(np.float32)
    lat6 = np.stack(frame.lat6.to_numpy()); latm = (~np.isnan(lat6).any(1)).astype(np.float32)
    lat6 = ((lat6-LAT_MEAN)/LAT_STD).astype(np.float32)
    vol = ((np.log(frame.V.to_numpy(float))-VOL_MEAN)/VOL_STD).astype(np.float32)
    sgraw = frame.spacegroup_number.to_numpy(float); sgm = np.isfinite(sgraw).astype(np.float32)
    sg = np.nan_to_num(sgraw).astype(np.int64)-1
    smap = {s:i for i,s in enumerate(SYSTEMS)}; sr = frame.crystal_system.map(smap)
    sysm = sr.notna().to_numpy(np.float32); sys_ = sr.fillna(0).to_numpy(np.int64)
    el = np.zeros((len(frame),len(VOCAB)),np.float32); elm=np.zeros(len(frame),np.float32)
    for i,els in enumerate(frame.elements):
        if len(els):
            elm[i]=1
            for e in els:
                if e in EL_IDX: el[i,EL_IDX[e]]=1
    return dict(lam=lam,lat6=lat6,latm=latm,vol=vol,volm=latm.copy(),sg=sg,sgm=sgm,
                sys_=sys_,sysm=sysm,el=el,elm=elm)

# %% [markdown]
# ### Класс `SpecDS`

# %%
class SpecDS(Dataset):
    def __init__(self, frame): self.row=frame.row_idx.to_numpy(np.int64); self.L=build_labels(frame)
    def __len__(self): return len(self.row)
    def __getitem__(self,i):
        x=np.empty((2,GRID_N),np.float32); x[0]=X_MM[self.row[i]]; x[1]=M_MM[self.row[i]]; L=self.L
        return (torch.from_numpy(x),torch.from_numpy(L['lam'][i]),torch.from_numpy(L['lat6'][i]),
                torch.tensor(L['latm'][i]),torch.tensor(L['sg'][i]),torch.tensor(L['sgm'][i]),
                torch.tensor(L['sys_'][i]),torch.tensor(L['sysm'][i]),torch.from_numpy(L['el'][i]),
                torch.tensor(L['elm'][i]),torch.tensor(L['vol'][i]),torch.tensor(L['volm'][i]))

# %% [markdown]
# ### Класс `ResBlock`

# %%
class ResBlock(nn.Module):
    def __init__(self,cin,cout,stride=1):
        super().__init__(); self.conv1=nn.Conv1d(cin,cout,3,stride,1,bias=False); self.n1=nn.GroupNorm(8,cout)
        self.conv2=nn.Conv1d(cout,cout,3,padding=1,bias=False); self.n2=nn.GroupNorm(8,cout)
        self.skip=nn.Identity() if cin==cout and stride==1 else nn.Sequential(nn.Conv1d(cin,cout,1,stride,bias=False),nn.GroupNorm(8,cout))
    def forward(self,x):
        h=F.gelu(self.n1(self.conv1(x))); h=self.n2(self.conv2(h)); return F.gelu(h+self.skip(x))

# %% [markdown]
# ### Класс `XRDNetV2`

# %%
class XRDNetV2(nn.Module):
    def __init__(self,n_el,w=3):
        super().__init__(); c=[32*w,48*w,64*w,96*w,128*w,192*w,256*w]
        self.stem=nn.Sequential(nn.Conv1d(2,c[0],15,padding=7,bias=False),nn.GroupNorm(8,c[0]),nn.GELU())
        self.blocks=nn.Sequential(*[ResBlock(c[i],c[i+1],2) for i in range(6)])
        self.lam_mlp=nn.Sequential(nn.Linear(3,16*w),nn.GELU(),nn.Linear(16*w,16*w))
        self.trunk=nn.Sequential(nn.Linear(c[-1]+16*w,512*w),nn.GELU(),nn.Linear(512*w,512*w),nn.GELU())
        self.head_lat=nn.Linear(512*w,6); self.head_vol=nn.Linear(512*w,1); self.head_sg=nn.Linear(512*w,230)
        self.head_sys=nn.Linear(512*w,7); self.head_el=nn.Linear(512*w,n_el)
    def forward(self,x,lam):
        f=self.blocks(self.stem(x)); w=F.adaptive_avg_pool1d(x[:,1:2],f.shape[-1]).clamp_min(1e-3)
        z=torch.cat([(f*w).sum(-1)/w.sum(-1),self.lam_mlp(lam)],1); z=self.trunk(z)
        return dict(lat=self.head_lat(z),vol=self.head_vol(z).squeeze(-1),sg=self.head_sg(z),sys=self.head_sys(z),el=self.head_el(z))

# %% [markdown]
# ### Функция `masked_l1`

# %%
def masked_l1(p,t,m): return F.smooth_l1_loss(p[m>0],t[m>0]) if (m>0).sum() else p.new_zeros(())

# %% [markdown]
# ### Функция `masked_ce`

# %%
def masked_ce(p,t,m): return F.cross_entropy(p[m>0],t[m>0].long()) if (m>0).sum() else p.new_zeros(())

# %% [markdown]
# ### Функция `losses`

# %%
def losses(out,b):
    _,_,lat,latm,sg,sgm,sys_,sysm,el,elm,vol,volm=b; m=latm>0
    ll=F.smooth_l1_loss(out['lat'][m,:3],lat[m,:3]) if m.sum() else out['lat'].new_zeros(())
    la=F.smooth_l1_loss(out['lat'][m,3:],lat[m,3:]) if m.sum() else out['lat'].new_zeros(())
    me=elm>0; le=F.binary_cross_entropy_with_logits(out['el'][me],el[me]) if me.sum() else out['el'].new_zeros(())
    d=dict(lat=ll,ang=la,vol=masked_l1(out['vol'],vol,volm),sg=masked_ce(out['sg'],sg,sgm),sys=masked_ce(out['sys'],sys_,sysm),el=le)
    return d, ll+2*la+.5*d['vol']+d['sg']+d['sys']+d['el']

# %% [markdown]
# ### Функция `evaluate`

# %%
@torch.no_grad()
def evaluate(model,loader):
    model.eval(); rows=[]
    for b in loader:
        b=[x.to(DEVICE) for x in b]
        with torch.autocast('cuda',dtype=torch.float16,enabled=DEVICE.type=='cuda'): out=model(b[0],b[1])
        _,_,lat,latm,sg,sgm,sys_,sysm,el,elm,vol,volm=b
        lp=out['lat'].float().cpu().numpy()*LAT_STD+LAT_MEAN; lp[:,:3]=np.exp(lp[:,:3])
        lt=lat.cpu().numpy()*LAT_STD+LAT_MEAN; lt[:,:3]=np.exp(lt[:,:3])
        for i in range(len(lat)):
            pe=frozenset(np.where(torch.sigmoid(out['el'][i]).cpu().numpy()>.5)[0]); te=frozenset(np.where(el[i].cpu().numpy()>.5)[0])
            rows.append(dict(sg_ok=float(sgm[i]>0 and out['sg'][i].argmax()==sg[i]),sg_top5=float(sgm[i]>0 and sg[i] in out['sg'][i].topk(5).indices),
                sys_ok=float(sysm[i]>0 and out['sys'][i].argmax()==sys_[i]),mae_a=abs(lp[i,0]-lt[i,0]) if latm[i]>0 else np.nan,
                mae_a_med=abs(lp[i,0]-lt[i,0]) if latm[i]>0 else np.nan,mae_ang=np.abs(lp[i,3:]-lt[i,3:]).mean() if latm[i]>0 else np.nan,
                pred_el=pe,true_el=te,elm=float(elm[i]),sgm=float(sgm[i]),sysm=float(sysm[i]),latm=float(latm[i])))
    model.train(); d=pd.DataFrame(rows); r={'n':len(d),'sg_n':int(d.sgm.sum())}
    for key,mask,col in [('sg_acc',d.sgm>0,'sg_ok'),('sg_top5',d.sgm>0,'sg_top5'),('sys_acc',d.sysm>0,'sys_ok')]: r[key]=d.loc[mask,col].mean() if mask.any() else np.nan
    v=d[d.latm>0]; r['mae_a']=v.mae_a.mean() if len(v) else np.nan; r['mae_a_med']=v.mae_a.median() if len(v) else np.nan; r['mae_ang']=v.mae_ang.mean() if len(v) else np.nan
    v=d[d.elm>0]; tp=sum(len(x.pred_el&x.true_el) for _,x in v.iterrows()); fp=sum(len(x.pred_el-x.true_el) for _,x in v.iterrows()); fn=sum(len(x.true_el-x.pred_el) for _,x in v.iterrows()); p=tp/max(tp+fp,1); q=tp/max(tp+fn,1); r['el_f1_micro']=2*p*q/max(p+q,1e-9); r['el_exact']=float((v.pred_el==v.true_el).mean()) if len(v) else np.nan
    return r

# %% [markdown]
# ### Функция `train_fold`

# %%
def train_fold(train_frame,val_frame,epochs):
    model=XRDNetV2(len(VOCAB),W).to(DEVICE); opt=torch.optim.AdamW(model.parameters(),lr=HP['lr'],weight_decay=HP['wd']); scaler=torch.amp.GradScaler('cuda',enabled=DEVICE.type=='cuda')
    tr=DataLoader(SpecDS(train_frame),batch_size=HP['batch'],shuffle=True,pin_memory=True); va=DataLoader(SpecDS(val_frame),batch_size=HP['batch'],shuffle=False,pin_memory=True)
    total=epochs*len(tr); warm=max(1,int(total*HP['warmup_frac'])); sched=torch.optim.lr_scheduler.LambdaLR(opt,lambda s:s/warm if s<warm else .5*(1+math.cos(math.pi*min((s-warm)/max(total-warm,1),1))))
    best=-1; best_ep=0; state=None
    for ep in range(epochs):
        for b in tr:
            b=[x.to(DEVICE,non_blocking=True) for x in b]
            with torch.autocast('cuda',dtype=torch.float16,enabled=DEVICE.type=='cuda'): _,total_loss=losses(model(b[0],b[1]),b)
            opt.zero_grad(set_to_none=True); scaler.scale(total_loss).backward(); scaler.unscale_(opt); nn.utils.clip_grad_norm_(model.parameters(),HP['clip']); scaler.step(opt); scaler.update(); sched.step()
        m=evaluate(model,va); score=(m.get('sys_acc') or 0)+(m.get('el_f1_micro') or 0)+.5*(m.get('sg_acc') or 0)
        print(f'epoch {ep+1:3d} | sys {m.get("sys_acc",np.nan):.3f} sg {m.get("sg_acc",np.nan):.3f} el {m.get("el_f1_micro",np.nan):.3f} mae_a {m.get("mae_a",np.nan):.2f}',flush=True)
        if score>best: best=score; best_ep=ep+1; state={k:v.detach().cpu().clone() for k,v in model.state_dict().items()}
    model.load_state_dict(state); return model,best_ep

# %% [markdown]
# ### Запуск эксперимента и сохранение результатов

# %%
folds=list(GroupKFold(n_splits=HP['n_folds']).split(ft,groups=ft.conn_key)); folds=folds[:1] if MODE=='quick' else folds
fold_metrics=[]; best_epochs=[]; t0=time.time()
for k,(tr_i,va_i) in enumerate(folds):
    print(f'\n===== REAL-ONLY FOLD {k+1}/{len(folds)} ====='); model,ep=train_fold(ft.iloc[tr_i].reset_index(drop=True),ft.iloc[va_i].reset_index(drop=True),HP['epochs']); best_epochs.append(ep)
    m=evaluate(model,DataLoader(SpecDS(ft.iloc[va_i].reset_index(drop=True)),batch_size=HP['batch'],pin_memory=True)); fold_metrics.append(m); print('best epoch',ep,'|',m); del model; torch.cuda.empty_cache()
rows=[]
for key in ['sys_acc','sg_acc','sg_top5','el_f1_micro','el_exact','mae_a','mae_a_med','mae_ang']:
    v=[m.get(key,np.nan) for m in fold_metrics]; rows.append(dict(metric=key,real_only=np.nanmean(v),std=np.nanstd(v),folds=len(v)))
summary=pd.DataFrame(rows); print(summary.to_string(index=False)); summary.to_csv(OUT/'real_only_v2_cv_summary.csv',index=False)
old=OUT/'ft_v2_cv_summary.csv'
if old.exists():
    prev=pd.read_csv(old); cmp=summary[['metric','real_only']].merge(prev[['metric','after_ft']],on='metric',how='outer'); cmp['synthetic_pretrain_plus_real_ft']=pd.to_numeric(cmp.after_ft,errors='coerce'); cmp['difference_real_only_minus_ft']=cmp.real_only-cmp.synthetic_pretrain_plus_real_ft; print('\n===== COMPARISON ====='); print(cmp.to_string(index=False)); cmp.to_csv(OUT/'real_only_vs_ft_v2_comparison.csv',index=False)
print('elapsed min:',(time.time()-t0)/60)
# Out:
# ===== REAL-ONLY FOLD 1/5 =====
# epoch   1 | sys 0.215 sg 0.000 el 0.106 mae_a 3.85
# epoch   2 | sys 0.313 sg 0.000 el 0.097 mae_a 3.86
# epoch   3 | sys 0.329 sg 0.052 el 0.237 mae_a 3.58
# epoch   4 | sys 0.333 sg 0.022 el 0.233 mae_a 3.55
# epoch   5 | sys 0.348 sg 0.037 el 0.233 mae_a 3.65
# epoch   6 | sys 0.292 sg 0.067 el 0.236 mae_a 3.74
# epoch   7 | sys 0.306 sg 0.052 el 0.254 mae_a 3.59
# epoch   8 | sys 0.325 sg 0.067 el 0.254 mae_a 3.58
# epoch   9 | sys 0.340 sg 0.052 el 0.319 mae_a 3.61
# epoch  10 | sys 0.312 sg 0.000 el 0.307 mae_a 3.56
# epoch  11 | sys 0.335 sg 0.052 el 0.351 mae_a 3.57
# epoch  12 | sys 0.329 sg 0.059 el 0.308 mae_a 3.58
# epoch  13 | sys 0.325 sg 0.022 el 0.303 mae_a 3.56
# epoch  14 | sys 0.331 sg 0.067 el 0.307 mae_a 3.67
# epoch  15 | sys 0.331 sg 0.015 el 0.301 mae_a 3.52
# epoch  16 | sys 0.331 sg 0.030 el 0.352 mae_a 3.59
# epoch  17 | sys 0.335 sg 0.059 el 0.322 mae_a 3.56
# epoch  18 | sys 0.358 sg 0.067 el 0.305 mae_a 3.54
# epoch  19 | sys 0.338 sg 0.052 el 0.346 mae_a 3.47
# epoch  20 | sys 0.294 sg 0.052 el 0.373 mae_a 3.49
# epoch  21 | sys 0.356 sg 0.052 el 0.351 mae_a 3.58
# epoch  22 | sys 0.337 sg 0.044 el 0.405 mae_a 3.49
# epoch  23 | sys 0.356 sg 0.059 el 0.336 mae_a 3.62
# epoch  24 | sys 0.348 sg 0.067 el 0.364 mae_a 3.44
# epoch  25 | sys 0.369 sg 0.074 el 0.335 mae_a 3.44
# epoch  26 | sys 0.348 sg 0.059 el 0.394 mae_a 3.39
# epoch  27 | sys 0.329 sg 0.044 el 0.376 mae_a 3.41
# epoch  28 | sys 0.375 sg 0.081 el 0.403 mae_a 3.35
# epoch  29 | sys 0.354 sg 0.081 el 0.446 mae_a 3.33
# epoch  30 | sys 0.392 sg 0.059 el 0.368 mae_a 3.40
# epoch  31 | sys 0.413 sg 0.074 el 0.386 mae_a 3.42
# epoch  32 | sys 0.392 sg 0.074 el 0.457 mae_a 3.38
# epoch  33 | sys 0.408 sg 0.074 el 0.429 mae_a 3.32
# epoch  34 | sys 0.427 sg 0.074 el 0.420 mae_a 3.21
# epoch  35 | sys 0.446 sg 0.081 el 0.474 mae_a 3.08
# epoch  36 | sys 0.456 sg 0.081 el 0.411 mae_a 3.06
# epoch  37 | sys 0.477 sg 0.074 el 0.429 mae_a 3.03
# epoch  38 | sys 0.462 sg 0.074 el 0.440 mae_a 3.06
# epoch  39 | sys 0.492 sg 0.074 el 0.438 mae_a 3.01
# epoch  40 | sys 0.485 sg 0.074 el 0.432 mae_a 2.98
# epoch  41 | sys 0.512 sg 0.074 el 0.454 mae_a 2.99
# epoch  42 | sys 0.508 sg 0.074 el 0.455 mae_a 3.03
# epoch  43 | sys 0.523 sg 0.074 el 0.447 mae_a 2.93
# epoch  44 | sys 0.538 sg 0.074 el 0.457 mae_a 3.03
# epoch  45 | sys 0.513 sg 0.074 el 0.456 mae_a 2.99
# epoch  46 | sys 0.525 sg 0.074 el 0.487 mae_a 3.06
# epoch  47 | sys 0.521 sg 0.067 el 0.457 mae_a 3.03
# epoch  48 | sys 0.512 sg 0.074 el 0.490 mae_a 2.98
# epoch  49 | sys 0.554 sg 0.074 el 0.458 mae_a 3.01
# epoch  50 | sys 0.533 sg 0.074 el 0.449 mae_a 2.93
# epoch  51 | sys 0.546 sg 0.074 el 0.450 mae_a 2.99
# epoch  52 | sys 0.525 sg 0.074 el 0.458 mae_a 2.93
# epoch  53 | sys 0.538 sg 0.074 el 0.468 mae_a 2.92
# epoch  54 | sys 0.542 sg 0.074 el 0.462 mae_a 2.92
# epoch  55 | sys 0.565 sg 0.074 el 0.464 mae_a 2.93
# epoch  56 | sys 0.558 sg 0.074 el 0.456 mae_a 2.98
# epoch  57 | sys 0.573 sg 0.074 el 0.459 mae_a 2.95
# epoch  58 | sys 0.567 sg 0.074 el 0.459 mae_a 2.92
# epoch  59 | sys 0.546 sg 0.074 el 0.456 mae_a 2.93
# epoch  60 | sys 0.571 sg 0.074 el 0.461 mae_a 2.91
# epoch  61 | sys 0.567 sg 0.074 el 0.462 mae_a 2.91
# epoch  62 | sys 0.573 sg 0.074 el 0.461 mae_a 2.91
# epoch  63 | sys 0.567 sg 0.074 el 0.460 mae_a 2.91
# epoch  64 | sys 0.571 sg 0.074 el 0.460 mae_a 2.91
# epoch  65 | sys 0.571 sg 0.074 el 0.461 mae_a 2.91
# best epoch 62 | {'n': 695, 'sg_n': 135, 'sg_acc': np.float64(0.07407407407407407), 'sg_top5': np.float64(0.0962962962962963), 'sys_acc': np.float64(0.573076923076923), 'mae_a': np.float64(2.9109753242138825), 'mae_a_med': 1.5924850268650306, 'mae_ang': np.float64(4.432136539857715), 'el_f1_micro': 0.46095812900792155, 'el_exact': 0.1076923076923077}
#
# ===== REAL-ONLY FOLD 2/5 =====
# epoch   1 | sys 0.179 sg 0.023 el 0.097 mae_a 4.05
# epoch   2 | sys 0.464 sg 0.148 el 0.101 mae_a 3.83
# epoch   3 | sys 0.458 sg 0.091 el 0.000 mae_a 3.44
# epoch   4 | sys 0.448 sg 0.261 el 0.000 mae_a 3.21
# epoch   5 | sys 0.388 sg 0.250 el 0.234 mae_a 3.21
# epoch   6 | sys 0.379 sg 0.261 el 0.268 mae_a 3.24
# epoch   7 | sys 0.442 sg 0.250 el 0.274 mae_a 3.35
# epoch   8 | sys 0.468 sg 0.250 el 0.285 mae_a 3.27
# epoch   9 | sys 0.469 sg 0.330 el 0.278 mae_a 3.25
# epoch  10 | sys 0.341 sg 0.159 el 0.302 mae_a 3.86
# epoch  11 | sys 0.471 sg 0.250 el 0.313 mae_a 3.23
# epoch  12 | sys 0.466 sg 0.307 el 0.345 mae_a 3.24
# epoch  13 | sys 0.451 sg 0.125 el 0.317 mae_a 3.23
# epoch  14 | sys 0.455 sg 0.352 el 0.351 mae_a 3.24
# epoch  15 | sys 0.457 sg 0.216 el 0.432 mae_a 3.26
# epoch  16 | sys 0.471 sg 0.307 el 0.394 mae_a 3.38
# epoch  17 | sys 0.457 sg 0.250 el 0.430 mae_a 3.25
# epoch  18 | sys 0.469 sg 0.284 el 0.372 mae_a 3.24
# epoch  19 | sys 0.460 sg 0.295 el 0.399 mae_a 3.23
# epoch  20 | sys 0.453 sg 0.261 el 0.447 mae_a 3.32
# epoch  21 | sys 0.475 sg 0.295 el 0.396 mae_a 3.17
# epoch  22 | sys 0.457 sg 0.341 el 0.521 mae_a 3.24
# epoch  23 | sys 0.469 sg 0.398 el 0.450 mae_a 3.24
# epoch  24 | sys 0.457 sg 0.295 el 0.409 mae_a 3.23
# epoch  25 | sys 0.458 sg 0.352 el 0.463 mae_a 3.20
# epoch  26 | sys 0.433 sg 0.352 el 0.368 mae_a 3.21
# epoch  27 | sys 0.473 sg 0.375 el 0.398 mae_a 3.21
# epoch  28 | sys 0.466 sg 0.330 el 0.409 mae_a 3.25
# epoch  29 | sys 0.477 sg 0.375 el 0.375 mae_a 3.13
# epoch  30 | sys 0.412 sg 0.398 el 0.434 mae_a 3.10
# epoch  31 | sys 0.502 sg 0.398 el 0.451 mae_a 3.12
# epoch  32 | sys 0.457 sg 0.420 el 0.408 mae_a 3.19
# epoch  33 | sys 0.509 sg 0.409 el 0.397 mae_a 3.02
# epoch  34 | sys 0.513 sg 0.398 el 0.484 mae_a 2.95
# epoch  35 | sys 0.491 sg 0.455 el 0.440 mae_a 3.08
# epoch  36 | sys 0.520 sg 0.443 el 0.489 mae_a 2.93
# epoch  37 | sys 0.558 sg 0.420 el 0.481 mae_a 2.94
# epoch  38 | sys 0.529 sg 0.432 el 0.470 mae_a 2.96
# epoch  39 | sys 0.523 sg 0.443 el 0.481 mae_a 2.94
# epoch  40 | sys 0.531 sg 0.455 el 0.509 mae_a 2.84
# epoch  41 | sys 0.540 sg 0.443 el 0.490 mae_a 2.89
# epoch  42 | sys 0.542 sg 0.455 el 0.479 mae_a 2.91
# epoch  43 | sys 0.576 sg 0.432 el 0.517 mae_a 2.79
# epoch  44 | sys 0.570 sg 0.420 el 0.518 mae_a 2.78
# epoch  45 | sys 0.569 sg 0.432 el 0.526 mae_a 2.76
# epoch  46 | sys 0.578 sg 0.432 el 0.510 mae_a 2.83
# epoch  47 | sys 0.592 sg 0.432 el 0.521 mae_a 2.79
# epoch  48 | sys 0.588 sg 0.443 el 0.512 mae_a 2.71
# epoch  49 | sys 0.594 sg 0.443 el 0.520 mae_a 2.70
# epoch  50 | sys 0.599 sg 0.420 el 0.513 mae_a 2.70
# epoch  51 | sys 0.596 sg 0.420 el 0.518 mae_a 2.73
# epoch  52 | sys 0.614 sg 0.432 el 0.511 mae_a 2.74
# epoch  53 | sys 0.579 sg 0.420 el 0.520 mae_a 2.70
# epoch  54 | sys 0.585 sg 0.420 el 0.520 mae_a 2.69
# epoch  55 | sys 0.596 sg 0.432 el 0.524 mae_a 2.68
# epoch  56 | sys 0.596 sg 0.420 el 0.517 mae_a 2.69
# epoch  57 | sys 0.590 sg 0.432 el 0.510 mae_a 2.67
# epoch  58 | sys 0.601 sg 0.420 el 0.514 mae_a 2.67
# epoch  59 | sys 0.594 sg 0.432 el 0.511 mae_a 2.67
# epoch  60 | sys 0.606 sg 0.432 el 0.515 mae_a 2.67
# epoch  61 | sys 0.606 sg 0.432 el 0.517 mae_a 2.66
# epoch  62 | sys 0.603 sg 0.432 el 0.518 mae_a 2.66
# epoch  63 | sys 0.601 sg 0.420 el 0.517 mae_a 2.67
# epoch  64 | sys 0.601 sg 0.420 el 0.518 mae_a 2.66
# epoch  65 | sys 0.601 sg 0.420 el 0.518 mae_a 2.66
# best epoch 52 | {'n': 695, 'sg_n': 88, 'sg_acc': np.float64(0.4318181818181818), 'sg_top5': np.float64(0.5), 'sys_acc': np.float64(0.6137184115523465), 'mae_a': np.float64(2.735308551120883), 'mae_a_med': 1.59019356441277, 'mae_ang': np.float64(4.466325296544145), 'el_f1_micro': 0.5109430959013131, 'el_exact': 0.22541966426858512}
#
# ===== REAL-ONLY FOLD 3/5 =====
# epoch   1 | sys 0.187 sg 0.000 el 0.062 mae_a 4.00
# epoch   2 | sys 0.302 sg 0.034 el 0.064 mae_a 4.02
# epoch   3 | sys 0.310 sg 0.411 el 0.000 mae_a 3.76
# epoch   4 | sys 0.296 sg 0.041 el 0.204 mae_a 3.73
# epoch   5 | sys 0.318 sg 0.068 el 0.208 mae_a 3.88
# epoch   6 | sys 0.316 sg 0.370 el 0.235 mae_a 3.69
# epoch   7 | sys 0.286 sg 0.274 el 0.330 mae_a 3.70
# epoch   8 | sys 0.310 sg 0.288 el 0.327 mae_a 3.69
# epoch   9 | sys 0.320 sg 0.267 el 0.328 mae_a 3.70
# epoch  10 | sys 0.286 sg 0.342 el 0.337 mae_a 3.67
# epoch  11 | sys 0.280 sg 0.240 el 0.309 mae_a 3.75
# epoch  12 | sys 0.322 sg 0.253 el 0.343 mae_a 3.76
# epoch  13 | sys 0.294 sg 0.171 el 0.347 mae_a 3.68
# epoch  14 | sys 0.320 sg 0.164 el 0.339 mae_a 3.63
# epoch  15 | sys 0.316 sg 0.212 el 0.375 mae_a 3.67
# epoch  16 | sys 0.308 sg 0.418 el 0.364 mae_a 3.65
# epoch  17 | sys 0.308 sg 0.205 el 0.372 mae_a 3.69
# epoch  18 | sys 0.338 sg 0.192 el 0.385 mae_a 3.59
# epoch  19 | sys 0.306 sg 0.233 el 0.355 mae_a 3.58
# epoch  20 | sys 0.320 sg 0.226 el 0.371 mae_a 3.64
# epoch  21 | sys 0.322 sg 0.226 el 0.445 mae_a 3.56
# epoch  22 | sys 0.330 sg 0.226 el 0.460 mae_a 3.60
# epoch  23 | sys 0.336 sg 0.240 el 0.450 mae_a 3.63
# epoch  24 | sys 0.356 sg 0.226 el 0.430 mae_a 3.59
# epoch  25 | sys 0.344 sg 0.233 el 0.457 mae_a 3.58
# epoch  26 | sys 0.324 sg 0.226 el 0.459 mae_a 3.58
# epoch  27 | sys 0.346 sg 0.233 el 0.447 mae_a 3.55
# epoch  28 | sys 0.352 sg 0.240 el 0.525 mae_a 3.45
# epoch  29 | sys 0.364 sg 0.329 el 0.427 mae_a 3.42
# epoch  30 | sys 0.372 sg 0.240 el 0.515 mae_a 3.34
# epoch  31 | sys 0.394 sg 0.233 el 0.493 mae_a 3.36
# epoch  32 | sys 0.392 sg 0.247 el 0.527 mae_a 3.40
# epoch  33 | sys 0.404 sg 0.247 el 0.484 mae_a 3.24
# epoch  34 | sys 0.427 sg 0.233 el 0.545 mae_a 3.21
# epoch  35 | sys 0.427 sg 0.240 el 0.527 mae_a 3.04
# epoch  36 | sys 0.447 sg 0.240 el 0.538 mae_a 3.04
# epoch  37 | sys 0.419 sg 0.233 el 0.540 mae_a 3.03
# epoch  38 | sys 0.439 sg 0.240 el 0.524 mae_a 3.10
# epoch  39 | sys 0.441 sg 0.233 el 0.541 mae_a 3.01
# epoch  40 | sys 0.479 sg 0.240 el 0.538 mae_a 3.00
# epoch  41 | sys 0.453 sg 0.233 el 0.534 mae_a 3.00
# epoch  42 | sys 0.465 sg 0.281 el 0.541 mae_a 3.03
# epoch  43 | sys 0.487 sg 0.253 el 0.557 mae_a 3.02
# epoch  44 | sys 0.469 sg 0.233 el 0.539 mae_a 3.02
# epoch  45 | sys 0.477 sg 0.253 el 0.555 mae_a 2.93
# epoch  46 | sys 0.491 sg 0.274 el 0.543 mae_a 2.90
# epoch  47 | sys 0.507 sg 0.247 el 0.552 mae_a 2.98
# epoch  48 | sys 0.505 sg 0.267 el 0.553 mae_a 2.92
# epoch  49 | sys 0.497 sg 0.240 el 0.549 mae_a 2.96
# epoch  50 | sys 0.501 sg 0.274 el 0.549 mae_a 2.91
# epoch  51 | sys 0.517 sg 0.267 el 0.548 mae_a 2.87
# epoch  52 | sys 0.513 sg 0.240 el 0.545 mae_a 2.91
# epoch  53 | sys 0.511 sg 0.247 el 0.556 mae_a 2.90
# epoch  54 | sys 0.531 sg 0.253 el 0.550 mae_a 2.88
# epoch  55 | sys 0.513 sg 0.274 el 0.556 mae_a 2.87
# epoch  56 | sys 0.511 sg 0.267 el 0.556 mae_a 2.88
# epoch  57 | sys 0.513 sg 0.247 el 0.556 mae_a 2.87
# epoch  58 | sys 0.523 sg 0.247 el 0.552 mae_a 2.86
# epoch  59 | sys 0.525 sg 0.253 el 0.550 mae_a 2.84
# epoch  60 | sys 0.531 sg 0.247 el 0.547 mae_a 2.84
# epoch  61 | sys 0.533 sg 0.253 el 0.548 mae_a 2.84
# epoch  62 | sys 0.531 sg 0.253 el 0.551 mae_a 2.84
# epoch  63 | sys 0.539 sg 0.253 el 0.549 mae_a 2.84
# epoch  64 | sys 0.539 sg 0.253 el 0.550 mae_a 2.84
# epoch  65 | sys 0.539 sg 0.253 el 0.550 mae_a 2.84
# best epoch 64 | {'n': 695, 'sg_n': 146, 'sg_acc': np.float64(0.2534246575342466), 'sg_top5': np.float64(0.5342465753424658), 'sys_acc': np.float64(0.5392354124748491), 'mae_a': np.float64(2.8377449020367), 'mae_a_med': 1.710601196685733, 'mae_ang': np.float64(4.459527689697539), 'el_f1_micro': 0.5495978552278821, 'el_exact': 0.19254658385093168}
#
# ===== REAL-ONLY FOLD 4/5 =====
# epoch   1 | sys 0.243 sg 0.000 el 0.034 mae_a 3.99
# epoch   2 | sys 0.349 sg 0.000 el 0.036 mae_a 3.74
# epoch   3 | sys 0.385 sg 0.328 el 0.000 mae_a 3.46
# epoch   4 | sys 0.391 sg 0.504 el 0.222 mae_a 3.27
# epoch   5 | sys 0.385 sg 0.024 el 0.235 mae_a 3.54
# epoch   6 | sys 0.354 sg 0.320 el 0.231 mae_a 3.44
# epoch   7 | sys 0.259 sg 0.232 el 0.222 mae_a 3.46
# epoch   8 | sys 0.296 sg 0.424 el 0.241 mae_a 3.26
# epoch   9 | sys 0.389 sg 0.296 el 0.230 mae_a 3.30
# epoch  10 | sys 0.376 sg 0.440 el 0.241 mae_a 3.48
# epoch  11 | sys 0.321 sg 0.472 el 0.249 mae_a 3.44
# epoch  12 | sys 0.356 sg 0.480 el 0.235 mae_a 3.48
# epoch  13 | sys 0.381 sg 0.472 el 0.247 mae_a 3.26
# epoch  14 | sys 0.321 sg 0.512 el 0.301 mae_a 3.29
# epoch  15 | sys 0.338 sg 0.488 el 0.247 mae_a 3.35
# epoch  16 | sys 0.392 sg 0.528 el 0.300 mae_a 3.32
# epoch  17 | sys 0.327 sg 0.544 el 0.379 mae_a 3.28
# epoch  18 | sys 0.389 sg 0.544 el 0.305 mae_a 3.30
# epoch  19 | sys 0.370 sg 0.480 el 0.345 mae_a 3.29
# epoch  20 | sys 0.378 sg 0.560 el 0.358 mae_a 3.45
# epoch  21 | sys 0.349 sg 0.512 el 0.351 mae_a 3.38
# epoch  22 | sys 0.380 sg 0.472 el 0.371 mae_a 3.26
# epoch  23 | sys 0.385 sg 0.552 el 0.367 mae_a 3.31
# epoch  24 | sys 0.383 sg 0.544 el 0.367 mae_a 3.28
# epoch  25 | sys 0.391 sg 0.560 el 0.382 mae_a 3.23
# epoch  26 | sys 0.352 sg 0.368 el 0.343 mae_a 3.33
# epoch  27 | sys 0.392 sg 0.560 el 0.390 mae_a 3.20
# epoch  28 | sys 0.354 sg 0.568 el 0.377 mae_a 3.19
# epoch  29 | sys 0.407 sg 0.560 el 0.440 mae_a 3.21
# epoch  30 | sys 0.381 sg 0.672 el 0.400 mae_a 3.20
# epoch  31 | sys 0.414 sg 0.712 el 0.388 mae_a 3.16
# epoch  32 | sys 0.411 sg 0.648 el 0.417 mae_a 3.14
# epoch  33 | sys 0.389 sg 0.696 el 0.447 mae_a 3.42
# epoch  34 | sys 0.418 sg 0.704 el 0.395 mae_a 3.25
# epoch  35 | sys 0.418 sg 0.704 el 0.431 mae_a 3.08
# epoch  36 | sys 0.431 sg 0.704 el 0.460 mae_a 3.01
# epoch  37 | sys 0.432 sg 0.656 el 0.427 mae_a 2.99
# epoch  38 | sys 0.456 sg 0.720 el 0.402 mae_a 2.90
# epoch  39 | sys 0.454 sg 0.712 el 0.455 mae_a 2.79
# epoch  40 | sys 0.453 sg 0.704 el 0.434 mae_a 2.75
# epoch  41 | sys 0.471 sg 0.712 el 0.413 mae_a 2.80
# epoch  42 | sys 0.482 sg 0.712 el 0.477 mae_a 2.83
# epoch  43 | sys 0.474 sg 0.712 el 0.482 mae_a 2.71
# epoch  44 | sys 0.476 sg 0.680 el 0.500 mae_a 2.68
# epoch  45 | sys 0.511 sg 0.704 el 0.497 mae_a 3.20
# epoch  46 | sys 0.482 sg 0.712 el 0.463 mae_a 2.77
# epoch  47 | sys 0.504 sg 0.712 el 0.491 mae_a 2.68
# epoch  48 | sys 0.515 sg 0.640 el 0.494 mae_a 2.73
# epoch  49 | sys 0.529 sg 0.696 el 0.491 mae_a 2.65
# epoch  50 | sys 0.507 sg 0.664 el 0.494 mae_a 2.76
# epoch  51 | sys 0.551 sg 0.664 el 0.501 mae_a 2.68
# epoch  52 | sys 0.505 sg 0.688 el 0.509 mae_a 2.65
# epoch  53 | sys 0.524 sg 0.712 el 0.512 mae_a 2.68
# epoch  54 | sys 0.533 sg 0.712 el 0.509 mae_a 2.65
# epoch  55 | sys 0.547 sg 0.696 el 0.501 mae_a 2.62
# epoch  56 | sys 0.553 sg 0.704 el 0.502 mae_a 2.60
# epoch  57 | sys 0.542 sg 0.712 el 0.514 mae_a 2.61
# epoch  58 | sys 0.549 sg 0.712 el 0.511 mae_a 2.61
# epoch  59 | sys 0.533 sg 0.696 el 0.509 mae_a 2.61
# epoch  60 | sys 0.540 sg 0.680 el 0.509 mae_a 2.59
# epoch  61 | sys 0.538 sg 0.696 el 0.512 mae_a 2.61
# epoch  62 | sys 0.544 sg 0.696 el 0.511 mae_a 2.62
# epoch  63 | sys 0.547 sg 0.696 el 0.509 mae_a 2.59
# epoch  64 | sys 0.546 sg 0.696 el 0.508 mae_a 2.59
# epoch  65 | sys 0.546 sg 0.696 el 0.509 mae_a 2.60
# best epoch 58 | {'n': 695, 'sg_n': 125, 'sg_acc': np.float64(0.712), 'sg_top5': np.float64(1.0), 'sys_acc': np.float64(0.5492700729927007), 'mae_a': np.float64(2.605909352717473), 'mae_a_med': 1.7946070662639038, 'mae_ang': np.float64(4.411635431178286), 'el_f1_micro': 0.5105130361648444, 'el_exact': 0.26844262295081966}
#
# ===== REAL-ONLY FOLD 5/5 =====
# epoch   1 | sys 0.343 sg 0.000 el 0.110 mae_a 3.95
# epoch   2 | sys 0.356 sg 0.000 el 0.122 mae_a 3.95
# epoch   3 | sys 0.347 sg 0.000 el 0.000 mae_a 3.57
# epoch   4 | sys 0.370 sg 0.211 el 0.214 mae_a 3.59
# epoch   5 | sys 0.280 sg 0.079 el 0.222 mae_a 3.60
# epoch   6 | sys 0.349 sg 0.303 el 0.256 mae_a 3.50
# epoch   7 | sys 0.356 sg 0.316 el 0.288 mae_a 3.62
# epoch   8 | sys 0.358 sg 0.342 el 0.293 mae_a 3.50
# epoch   9 | sys 0.358 sg 0.263 el 0.283 mae_a 3.53
# epoch  10 | sys 0.366 sg 0.105 el 0.284 mae_a 3.55
# epoch  11 | sys 0.333 sg 0.368 el 0.291 mae_a 3.60
# epoch  12 | sys 0.356 sg 0.342 el 0.292 mae_a 3.54
# epoch  13 | sys 0.366 sg 0.276 el 0.297 mae_a 3.58
# epoch  14 | sys 0.362 sg 0.105 el 0.293 mae_a 3.57
# epoch  15 | sys 0.362 sg 0.276 el 0.288 mae_a 3.50
# epoch  16 | sys 0.375 sg 0.197 el 0.298 mae_a 3.59
# epoch  17 | sys 0.360 sg 0.342 el 0.295 mae_a 3.59
# epoch  18 | sys 0.360 sg 0.355 el 0.301 mae_a 3.63
# epoch  19 | sys 0.368 sg 0.171 el 0.340 mae_a 3.52
# epoch  20 | sys 0.392 sg 0.211 el 0.325 mae_a 3.51
# epoch  21 | sys 0.366 sg 0.355 el 0.371 mae_a 3.60
# epoch  22 | sys 0.352 sg 0.237 el 0.397 mae_a 3.62
# epoch  23 | sys 0.381 sg 0.342 el 0.376 mae_a 3.63
# epoch  24 | sys 0.352 sg 0.276 el 0.346 mae_a 3.67
# epoch  25 | sys 0.360 sg 0.342 el 0.401 mae_a 3.62
# epoch  26 | sys 0.379 sg 0.329 el 0.462 mae_a 3.46
# epoch  27 | sys 0.347 sg 0.316 el 0.401 mae_a 3.56
# epoch  28 | sys 0.390 sg 0.303 el 0.504 mae_a 3.53
# epoch  29 | sys 0.385 sg 0.342 el 0.429 mae_a 3.42
# epoch  30 | sys 0.392 sg 0.316 el 0.473 mae_a 3.37
# epoch  31 | sys 0.400 sg 0.355 el 0.422 mae_a 3.33
# epoch  32 | sys 0.398 sg 0.382 el 0.446 mae_a 3.42
# epoch  33 | sys 0.402 sg 0.316 el 0.446 mae_a 3.33
# epoch  34 | sys 0.400 sg 0.355 el 0.476 mae_a 3.39
# epoch  35 | sys 0.432 sg 0.355 el 0.503 mae_a 3.34
# epoch  36 | sys 0.453 sg 0.382 el 0.509 mae_a 3.33
# epoch  37 | sys 0.463 sg 0.316 el 0.466 mae_a 3.36
# epoch  38 | sys 0.467 sg 0.408 el 0.493 mae_a 3.29
# epoch  39 | sys 0.463 sg 0.355 el 0.475 mae_a 3.34
# epoch  40 | sys 0.484 sg 0.368 el 0.452 mae_a 3.34
# epoch  41 | sys 0.491 sg 0.382 el 0.499 mae_a 3.31
# epoch  42 | sys 0.510 sg 0.342 el 0.507 mae_a 3.22
# epoch  43 | sys 0.484 sg 0.342 el 0.527 mae_a 3.26
# epoch  44 | sys 0.501 sg 0.368 el 0.508 mae_a 3.19
# epoch  45 | sys 0.518 sg 0.342 el 0.491 mae_a 3.19
# epoch  46 | sys 0.514 sg 0.355 el 0.503 mae_a 3.15
# epoch  47 | sys 0.530 sg 0.355 el 0.514 mae_a 3.12
# epoch  48 | sys 0.520 sg 0.355 el 0.499 mae_a 3.21
# epoch  49 | sys 0.530 sg 0.355 el 0.486 mae_a 3.15
# epoch  50 | sys 0.528 sg 0.355 el 0.496 mae_a 3.16
# epoch  51 | sys 0.516 sg 0.368 el 0.515 mae_a 3.14
# epoch  52 | sys 0.541 sg 0.355 el 0.501 mae_a 3.12
# epoch  53 | sys 0.552 sg 0.355 el 0.486 mae_a 3.10
# epoch  54 | sys 0.547 sg 0.355 el 0.501 mae_a 3.08
# epoch  55 | sys 0.537 sg 0.355 el 0.496 mae_a 3.08
# epoch  56 | sys 0.550 sg 0.355 el 0.491 mae_a 3.07
# epoch  57 | sys 0.547 sg 0.355 el 0.498 mae_a 3.08
# epoch  58 | sys 0.556 sg 0.355 el 0.498 mae_a 3.10
# epoch  59 | sys 0.552 sg 0.355 el 0.494 mae_a 3.06
# epoch  60 | sys 0.562 sg 0.355 el 0.493 mae_a 3.05
# epoch  61 | sys 0.550 sg 0.355 el 0.498 mae_a 3.06
# epoch  62 | sys 0.558 sg 0.355 el 0.496 mae_a 3.05
# epoch  63 | sys 0.560 sg 0.355 el 0.497 mae_a 3.05
# epoch  64 | sys 0.558 sg 0.355 el 0.496 mae_a 3.05
# epoch  65 | sys 0.558 sg 0.355 el 0.497 mae_a 3.05
# best epoch 63 | {'n': 695, 'sg_n': 76, 'sg_acc': np.float64(0.35526315789473684), 'sg_top5': np.float64(1.0), 'sys_acc': np.float64(0.56), 'mae_a': np.float64(3.053650566593078), 'mae_a_med': 1.5507199929234452, 'mae_ang': np.float64(4.428524626343247), 'el_f1_micro': 0.4966832504145937, 'el_exact': 0.15365853658536585}
#      metric  real_only      std  folds
#     sys_acc   0.567060 0.025899      5
#      sg_acc   0.365316 0.210739      5
#     sg_top5   0.626109 0.341945      5
# el_f1_micro   0.505739 0.028498      5
#    el_exact   0.189552 0.055693      5
#       mae_a   2.828718 0.152192      5
#   mae_a_med   1.647721 0.090883      5
#     mae_ang   4.439630 0.020356      5
#
# ===== COMPARISON =====
#      metric  real_only  after_ft  synthetic_pretrain_plus_real_ft  difference_real_only_minus_ft
#    el_exact   0.189552     0.179                            0.179                       0.010552
# el_f1_micro   0.505739     0.501                            0.501                       0.004739
#       mae_a   2.828718     2.662                            2.662                       0.166718
#   mae_a_med   1.647721     1.523                            1.523                       0.124721
#     mae_ang   4.439630     4.574                            4.574                      -0.134370
#      sg_acc   0.365316     0.509                            0.509                      -0.143684
#     sg_top5   0.626109     0.676                            0.676                      -0.049891
#     sys_acc   0.567060     0.630                            0.630                      -0.062940
# elapsed min: 27.334977412223814
